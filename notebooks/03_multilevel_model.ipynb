# %% [markdown]
# # Multilevel Model: Variance Decomposition + FDR Testing
#
# Fit the three-level mixed model, report ICC decomposition (RQ1), fixed effect predictors (RQ2), and BH-corrected subject rankings.

# %%
import os
os.chdir(os.path.dirname(os.getcwd()) if os.path.basename(os.getcwd()) == "notebooks" else os.getcwd())
import sys
sys.path.insert(0, 'src')
import pandas as pd
from modeling import multilevel, testing

MODEL = 'gpt4o'
result, icc, blups = multilevel.run(MODEL)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#
# === gpt4o: n=14,042 questions, 57 subjects ===
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# ...

# %%
print('ICC Decomposition:')
for k, v in icc.items():
    print(f'  {k}: {v:.4f}')
# Out:
# ICC Decomposition:
#   icc_domain: 0.0000
#   icc_subject: 0.0792
#   icc_residual: 0.9208
#   var_domain: 0.0000
#   var_subject: 0.0129
#   var_residual: 0.1494

# %%
fdr = testing.run(MODEL)
fdr[fdr['reject']].sort_values('mean_gap', ascending=False)
# Out:
# gpt4o: 57/57 subjects rejected at FDR 0.05
#                             subject          domain    n  mean_gap   se_gap    t_stat       p_value         p_adj  reject
#                    professional_law      Humanities 1534  0.379648 0.012198 31.114280 3.677671e-165 2.096272e-163    True
#                     moral_scenarios      Humanities  895  0.483082 0.016627 29.037087 4.196842e-131 1.196100e-129    True
#              elementary_mathematics            STEM  378  0.302127 0.023382 12.904333  8.312697e-32  1.579412e-30    True
#             professional_psychology Social Sciences  612  0.163926 0.015139 10.819345  4.424273e-25  6.304588e-24    True
#             professional_accounting           Other  282  0.299120 0.026972 11.070321  7.029042e-24  8.013107e-23    True
#                            virology           Other  166  0.442346 0.038055 11.588713  4.238841e-23  4.026899e-22    True
# ...
